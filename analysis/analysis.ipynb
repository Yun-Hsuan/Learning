# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
#from sklearn.model_selection import cross_val_score
#from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing

def load_csv(fname):

    df = pd.read_csv(fname, index_col=0)
    label = np.array(df.columns)
    index = np.array(df.index)
    #index = np.array(df['Wafer.ID'])
    X = np.array(df)
    Y = X[:, -1]
    X = np.delete(X, -1, 1)

    return label, index, X, Y


if __name__ == '__main__':	

    fname = '../ggdata/ggdata_1000.csv'
    print " ==========  Loading the dataSet  ========== "
    
    label, index, X, Y = load_csv(fname)

    print " ========== Start Transform String to float ========== "
    print " ..."
    tf = preprocessing.LabelEncoder()
    tx = X.reshape(-1)
    tf.fit(tx)
    tx = tf.transform(tx)
    tx = np.reshape(tx, X.shape)
    print " ==========  End Transform String to float  ========== "

    print " ==== Fitting ..."
    clf = DecisionTreeClassifier(random_state=0)
    clf.fit(tx, Y)
    clf_err = 1.0 - clf.score(X, Y)

    print "Error: " + str(clf_err) + "\n\n"
    print "End ============"

    dot_data = tree.export_graphviz(clf, out_file = "Tree.dot")
    graph = pydotplus.graph_from_dot_data(dot_data)
    Image(graph.create_png())
# Out:
#  ==========  Loading the dataSet  ==========
#  ========== Start Transform String to float ==========
#  ...
#  ==========  End Transform String to float  ==========
#  ==== Fitting ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-764af656f81f> in <module>()
#      38     print " ==== Fitting ..."
#      39     clf = DecisionTreeClassifier(random_state=0)
# ---> 40     clf.fit(tx, Y)
#      41     clf_err = 1.0 - clf.score(X, Y)
#      42
#
# /usr/lib64/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     175
#     176         if is_classification:
# --> 177             check_classification_targets(y)
#     178             y = np.copy(y)
#     179
#
# /usr/lib64/python2.7/site-packages/sklearn/utils/multiclass.pyc in check_classification_targets(y)
# ...
